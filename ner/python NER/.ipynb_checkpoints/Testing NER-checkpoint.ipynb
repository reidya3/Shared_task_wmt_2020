# %%
from named_entity_recogniser import *

IN = "input/train.ende.df.short.tsv"
OUT = "output/masked.tsv"
entities = ["PERSON", "ORG", "PRODUCT", "WORK_OF_ART", "LOC"]

d = mask(IN, OUT, entities)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-550158f9f7c6> in <module>
#       5 entities = ["PERSON", "ORG", "PRODUCT", "WORK_OF_ART", "LOC"]
#       6
# ----> 7 d = mask(IN, OUT, entities)
#
# ~\Google Drive (sean.cummins26@mail.dcu.ie)\3rd_year\ca337\assignment_1_github\ner\python NER\named_entity_recogniser.py in mask(input_csv, output_csv, entities)
#      13 def mask(input_csv, output_csv, entities):
#      14         d = {}
# ---> 15         df = pd.read_csv(input_csv, sep='\t', index_col="index")
#      16
#      17         entity_count = 0
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File train.ende.df.short.tsv does not exist: 'train.ende.df.short.tsv'

# %% [markdown]
# # For some reason the exact same code doesn't work here?
#
# Running this code outside notebooks with the relevant files produces a new tsv with masked entities.

# %%
masked = pd.read_csv("masked.tsv",sep="\t", index_col="index")

# %%
masked.head(20)
# Out:
#                                                 original  \
# index
# 0       NE0***************** visited NE1****  at Frei...
# 1      However, a disappointing ninth in China meant ...
# 2      In his diary,  NE2** wrote that the release of...
# 3      Heavy arquebuses mounted on wagons were called...
# 4      Once  NE5********** salmon die off after spawn...
# 5      They engaged in crossfire at Guamaní River Bri...
# 6      Several WHA teams courted  NE8****  notably NE...
# 7      16  NE10****** in which redshirt freshman NE11...
# 8      On 12 April 1983,  NE12***********************...
# 9      After that, Chinese junks came to northern  NE...
# 10      NE14********* portrays The Baroness as one of...
# 11     The Roundhead besiegers made an effort to rais...
# 12     When legendary wrestler  NE18******** advised ...
# 13     Meanwhile, US garrisons in Japan continually d...
# 14     The cover depicted a photograph of The  NE25**...
# 15     The use of furrow widener or a longer mouldboa...
# 16     Differences in dimensionalities of phonons and...
# 17     Their lustre tarnishes rapidly in air due to o...
# 18      NE26**************** and the Future of the Hu...
# 19     They bundled him into a field and "tarred and ...
#
#                                              translation           scores  \
# index
# 0      1934 besuchte José Ortega y Gasset Husserl in ...  [100, 100, 100]
# 1      Eine enttäuschende Neunte in China bedeutete j...     [61, 70, 87]
# 2      In seinem Tagebuch, Chase schrieb, dass die Ve...     [52, 45, 49]
# 3      Schwere Arquebuses auf Waggons montiert wurden...     [61, 55, 85]
# 4      Sobald der nordpazifische Lachs nach dem Laich...     [91, 89, 87]
# 5      Sie verübten Kreuzfeuer an der Guamaní River B...     [61, 58, 88]
# 6      Mehrere WHA-Teams umworben Gretzky, insbesonde...    [100, 74, 88]
# 7      16 Penn State, in dem Rothemd-Neuling Jim Kell...     [58, 73, 88]
# 8      Am 12. April 1983 ernannte die Landmarks Prese...     [92, 69, 86]
# 9      Danach kamen chinesische Junks mit Gewürzen, V...     [59, 66, 85]
# 10     Sienna Miller porträtiert The Baroness als ein...     [73, 59, 66]
# 11     Die Roundhead Belagerer bemühten sich, eine ne...     [91, 90, 88]
# 12     Als der legendäre Wrestler Jake Roberts Orton ...     [56, 70, 63]
# 13     Unterdessen entsandten US-Garnisonen in Japan ...   [100, 72, 100]
# 14     Das Cover zeigt ein Foto von The Huxtable mit ...     [53, 67, 60]
# 15     Die Verwendung von Furchenwischer oder ein län...     [57, 52, 55]
# 16     Unterschiede in der Dimensionalität von Phonen...     [59, 65, 89]
# 17     Durch Oxidation trübt ihr Glanz schnell in der...     [90, 73, 89]
# 18     Renaissance Humanism and the Future of the Hum...        [1, 1, 1]
# 19     Sie bündelten ihn in ein Feld und "tarred und ...     [71, 54, 63]
#
#                      mean                                           z_scores  \
# index
# 0                   100.0  [0.9553316582231767, 1.5523622744336512, 0.850...
# 1       72.66666666666667  [-1.1951539386222017, 0.04217636328434989, -0....
# 2      48.666666666666664  [-1.6914198455865197, -1.2163118960067345, -3....
# 3                    67.0  [-1.1951539386222017, -0.7129165922903007, -0....
# 4                    89.0  [0.45906575125885857, 0.998627440345574, -0.31...
# 5                    69.0  [-1.1951539386222017, -0.5618980011753706, -0....
# 6       87.33333333333333  [0.9553316582231767, 0.24353448477092338, -0.2...
# 7                    73.0  [-1.3605759076103077, 0.19319495439928003, -0....
# 8       82.33333333333333  [0.5142064075882272, -0.008163167087293482, -0...
# 9                    70.0  [-1.305435251280939, -0.1591817582022236, -0.4...
# 10                   66.0  [-0.5334660626697776, -0.5115584708037272, -2....
# 11      89.66666666666667  [0.45906575125885857, 1.0489669707172173, -0.2...
# 12                   63.0  [-1.470857220269045, 0.04217636328434989, -2.4...
# 13      90.66666666666667  [0.2654514735602496, -0.9439568253313346, 0.85...
# 14                   60.0  [-1.636279189257151, -0.10884222783058023, -2....
# 15     54.666666666666664  [-1.4157165639396765, -0.8639351834052308, -3....
# 16                   71.0  [-1.305435251280939, -0.20952128857386698, -0....
# 17                   84.0  [0.40392509492948986, 0.19319495439928003, -0....
# 18                    1.0  [-4.503593318384322, -3.4312512323590427, -8.0...
# 19     62.666666666666664  [-0.643747375328515, -0.7632561226619441, -2.4...
#
#          z_mean  model_scores
# index
# 0      1.119409     -0.102446
# 1     -0.488591     -0.431046
# 2     -2.207007     -0.351719
# 3     -0.799946     -0.432696
# 4      0.381633     -0.392975
# 5     -0.660120     -0.346494
# 6      0.325186     -0.215494
# 7     -0.463563     -0.322855
# 8      0.034587     -0.252926
# 9     -0.652128     -0.311307
# 10    -1.079013     -0.296894
# 11     0.428242     -0.377884
# 12    -1.296385     -0.258461
# 13     0.057342     -0.263320
# 14    -1.491352     -0.421900
# 15    -1.818673     -0.556688
# 16    -0.549593     -0.412295
# 17     0.154433     -0.447433
# 18    -5.314497     -0.125498
# 19    -1.289159     -0.463036
